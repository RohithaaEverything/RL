# %%
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random

class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        states, actions, rewards, next_states, dones = zip(*random.sample(self.buffer, batch_size))
        return np.array(states), np.array(actions), np.array(rewards), np.array(next_states), np.array(dones)

    def __len__(self):
        return len(self.buffer)

def epsilon_greedy_policy(state, epsilon):
    if np.random.rand() < epsilon:
        return np.random.randint(env.action_space.n)
    else:
        with torch.no_grad():
            q_values = model(torch.tensor(state, dtype=torch.float32))
            return np.argmax(q_values.numpy())

def train_model(model, optimizer, batch_size, gamma):
    if len(buffer) < batch_size:
        return
    states, actions, rewards, next_states, dones = buffer.sample(batch_size)
    states = torch.tensor(states, dtype=torch.float32)
    actions = torch.tensor(actions, dtype=torch.long)
    rewards = torch.tensor(rewards, dtype=torch.float32)
    next_states = torch.tensor(next_states, dtype=torch.float32)
    dones = torch.tensor(dones, dtype=torch.float32)

    q_values = model(states)
    next_q_values = model(next_states)
    q_value = q_values.gather(1, actions.unsqueeze(1)).squeeze(1)
    next_q_value = next_q_values.max(1)[0]
    expected_q_value = rewards + gamma * next_q_value * (1 - dones)

    loss = F.smooth_l1_loss(q_value, expected_q_value)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# Initialize environment and hyperparameters
env = gym.make('CartPole-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
model = DQN(state_size, action_size)
optimizer = optim.Adam(model.parameters(), lr=0.001)
buffer = ReplayBuffer(capacity=10000)
gamma = 0.99
epsilon = 1.0
epsilon_decay = 0.995
min_epsilon = 0.01
batch_size = 64
num_episodes = 100

# Training loop
for episode in range(num_episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = epsilon_greedy_policy(state, epsilon)
        next_state, reward, done, _ = env.step(action)
        total_reward += reward
        buffer.push(state, action, reward, next_state, done)
        state = next_state

        train_model(model, optimizer, batch_size, gamma)

        if epsilon > min_epsilon:
            epsilon *= epsilon_decay

    print(f"Episode: {episode + 1}, Total Reward: {total_reward}")

# Evaluate the trained model
total_rewards = []
num_eval_episodes = 10

for _ in range(num_eval_episodes):
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        action = np.argmax(model(torch.tensor(state, dtype=torch.float32)).detach().numpy())
        next_state, reward, done, _ = env.step(action)
        state = next_state
        episode_reward += reward

    total_rewards.append(episode_reward)

avg_reward = sum(total_rewards) / num_eval_episodes
print(f"Average Reward over {num_eval_episodes} episodes: {avg_reward}")
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode: 1, Total Reward: 20.0
# Episode: 2, Total Reward: 13.0
# Episode: 3, Total Reward: 13.0
# Episode: 4, Total Reward: 19.0
# Episode: 5, Total Reward: 16.0
# Episode: 6, Total Reward: 18.0
# Episode: 7, Total Reward: 14.0
# Episode: 8, Total Reward: 24.0
# Episode: 9, Total Reward: 9.0
# Episode: 10, Total Reward: 35.0
# Episode: 11, Total Reward: 15.0
# Episode: 12, Total Reward: 19.0
# Episode: 13, Total Reward: 46.0
# Episode: 14, Total Reward: 9.0
# Episode: 15, Total Reward: 19.0
# Episode: 16, Total Reward: 17.0
# Episode: 17, Total Reward: 9.0
# Episode: 18, Total Reward: 21.0
# Episode: 19, Total Reward: 14.0
# Episode: 20, Total Reward: 17.0
# Episode: 21, Total Reward: 26.0
# Episode: 22, Total Reward: 13.0
# Episode: 23, Total Reward: 16.0
# Episode: 24, Total Reward: 24.0
# Episode: 25, Total Reward: 34.0
# Episode: 26, Total Reward: 28.0
# Episode: 27, Total Reward: 28.0
# Episode: 28, Total Reward: 24.0
# Episode: 29, Total Reward: 38.0
# Episode: 30, Total Reward: 29.0
# Episode: 31, Total Reward: 33.0
# Episode: 32, Total Reward: 26.0
# Episode: 33, Total Reward: 25.0
# Episode: 34, Total Reward: 23.0
# Episode: 35, Total Reward: 39.0
# Episode: 36, Total Reward: 48.0
# Episode: 37, Total Reward: 31.0
# Episode: 38, Total Reward: 28.0
# Episode: 39, Total Reward: 9.0
# Episode: 40, Total Reward: 16.0
# Episode: 41, Total Reward: 52.0
# Episode: 42, Total Reward: 21.0
# Episode: 43, Total Reward: 27.0
# Episode: 44, Total Reward: 32.0
# Episode: 45, Total Reward: 54.0
# Episode: 46, Total Reward: 39.0
# Episode: 47, Total Reward: 64.0
# Episode: 48, Total Reward: 32.0
# Episode: 49, Total Reward: 39.0
# Episode: 50, Total Reward: 58.0
# Episode: 51, Total Reward: 54.0
# Episode: 52, Total Reward: 19.0
# Episode: 53, Total Reward: 68.0
# Episode: 54, Total Reward: 50.0
# Episode: 55, Total Reward: 38.0
# Episode: 56, Total Reward: 39.0
# Episode: 57, Total Reward: 63.0
# Episode: 58, Total Reward: 33.0
# Episode: 59, Total Reward: 26.0
# Episode: 60, Total Reward: 29.0
# Episode: 61, Total Reward: 51.0
# Episode: 62, Total Reward: 97.0
# Episode: 63, Total Reward: 86.0
# Episode: 64, Total Reward: 103.0
# Episode: 65, Total Reward: 99.0
# Episode: 66, Total Reward: 81.0
# Episode: 67, Total Reward: 129.0
# Episode: 68, Total Reward: 65.0
# Episode: 69, Total Reward: 53.0
# Episode: 70, Total Reward: 49.0
# Episode: 71, Total Reward: 107.0
# Episode: 72, Total Reward: 115.0
# Episode: 73, Total Reward: 149.0
# Episode: 74, Total Reward: 93.0
# Episode: 75, Total Reward: 41.0
# Episode: 76, Total Reward: 159.0
# Episode: 77, Total Reward: 87.0
# Episode: 78, Total Reward: 57.0
# Episode: 79, Total Reward: 66.0
# Episode: 80, Total Reward: 100.0
# Episode: 81, Total Reward: 51.0
# Episode: 82, Total Reward: 142.0
# Episode: 83, Total Reward: 178.0
# Episode: 84, Total Reward: 120.0
# Episode: 85, Total Reward: 65.0
# Episode: 86, Total Reward: 158.0
# Episode: 87, Total Reward: 167.0
# Episode: 88, Total Reward: 71.0
# Episode: 89, Total Reward: 83.0
# Episode: 90, Total Reward: 132.0
# Episode: 91, Total Reward: 134.0
# Episode: 92, Total Reward: 103.0
# Episode: 93, Total Reward: 173.0
# Episode: 94, Total Reward: 120.0
# Episode: 95, Total Reward: 111.0
# Episode: 96, Total Reward: 182.0
# Episode: 97, Total Reward: 137.0
# Episode: 98, Total Reward: 98.0
# Episode: 99, Total Reward: 150.0
# Episode: 100, Total Reward: 116.0
# Average Reward over 10 episodes: 165.4
